# %% [markdown]
# # Student Name: Yuan-Yao Lou
# # ECE 595 Machine Learning II
# # Project 1: CLDNN - Student Code
#
#
# ---
#
#
# \\

# %%
# Import necessary packages
import keras
import numpy as np
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout, Reshape, LSTM, InputLayer
import matplotlib.pyplot as plt
import cPickle
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #Part 0: Importing and normalizing data

# %%
# Import dataset and normalize to [0,1]
# Has shape (num_samples, 28, 28)
(data_train, labels_train), (data_test, labels_test) = fashion_mnist.load_data()
data_train = data_train / 255.0
data_test  = data_test / 255.0
data_train = data_train.reshape(60000, 28, 28, 1)
data_test  = data_test.reshape(10000, 28, 28, 1)

# Create labels as one-hot vectors
# labels_train and labels_test have shapes (60000, 10) and (10000, 10) respectively
labels_train = keras.utils.np_utils.to_categorical(labels_train, num_classes=10)
labels_test  = keras.utils.np_utils.to_categorical(labels_test,  num_classes=10)
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 3us/step
# 40960/29515 [=========================================] - 0s 3us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# 26435584/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step
# 4431872/4422102 [==============================] - 1s 0us/step

# %% [markdown]
# #Part 1: Plotting cross entropy

# %%
# Show cross-entropy loss function
# = Negative Log-Likelihood (NLL): L(y) = log(y), y in [0, 1]

prob = np.linspace(0.001, 1.000, 1000)
neg_log = -np.log(prob)

plt.figure()
plt.plot(prob, neg_log)
plt.xlabel("Probability")
plt.ylabel("NLL: -log(P)")
plt.yticks(np.arange(min(neg_log), max(neg_log)+1, 1.0))
plt.title("Negative Log-Likelihood (NLL) vs. Probability [0, 1]")
# Out:
# Text(0.5,1,'Negative Log-Likelihood (NLL) vs. Probability [0, 1]')

# %% [markdown]
# Answer the following questions:
#
#
# 1.   How is the the negative log-likelihood of p affected when p is small? How about when p is large?
#
#   ANS: The value of the Negative Log-Likelihood (NLL) of p drastically increases as p gets smaller. In contrast, the value of the negative log-likelihood of p gradually decreases as p gets larger.
#
# 2.   Why does the behavior of the negative log-likelihood function make it a good objective function for a minimization problem specifically when the output can be interpreted as a probability space?
#
#   ANS: First, we want to maximize the probability of choosing the correct category. Thus, we can maximize by "minimizing the negative" log-likelihood. Just as the plot shows, when the value of the NLL function goes to 0, the model has the maximized probability.
#
#   Next, regarding the probability space and the interaction with log behavior, let's take an example to further explain the behavior of NLL. If the probability of 4 possible classes is [0.1, 0.3, 0.5, 0.1], assume that the true answer is the fourth class ([0, 0, 0, 1]). The model with NLL produce -ln(0.1) = 2.3. However, the correct one would have been the third class. The model with NLL then produce -ln(0.5) = 0.69. We see that the better the prediction the lower the NLL loss, and that is exactly what we want.

# %% [markdown]
# #Part 2: Overfit CNN

# %%
# Create and train model architecture
def CNN_overfit(x1, x2, y):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()
    
    # 1st hidden layer with input
    # [Note] 
    #  - activation with sigmoid improves the performance
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', input_shape=(x1, x2, 1)))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))

    # output layer with Softmax
    # [Note]
    #  - Softmax activation function makes sure the probabilities sum up to 1.
    model.add(Dense(y, activation='softmax'))

    return model

# Create instance of CNN model graph
CNN_overfit = CNN_overfit(28, 28, 10)

# Compile model using an appropriate loss and optimizer algorithm
# [Note] 
#  - SGD is too strong, not causing overfitting
# [Reference] 
#  - RMSprop: https://towardsdatascience.com/understanding-rmsprop-faster-neural-network-learning-62e116fcf29a
#  - Trend in ML: https://karpathy.medium.com/a-peek-at-trends-in-machine-learning-ab8a1085a106
#  - Overfitting Handling: https://towardsdatascience.com/handling-overfitting-in-deep-learning-models-c760ee047c6e
CNN_overfit.compile(optimizer='rmsprop', 
                    loss='categorical_crossentropy', 
                    metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
# [Note] 
#  - set shuffle to True to improve the performance
history = CNN_overfit.fit(data_train, labels_train, 
                          validation_data = (data_test, labels_test),
                          epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training (* 100 to make it be %)
accuracy = CNN_overfit.evaluate(data_test, labels_test)
print("Accuracy: {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 12s 193us/step - loss: 1.8998 - accuracy: 0.5083 - val_loss: 0.8018 - val_accuracy: 0.6514
# Epoch 2/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.6693 - accuracy: 0.7497 - val_loss: 0.6619 - val_accuracy: 0.7322
# Epoch 3/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.5537 - accuracy: 0.7941 - val_loss: 0.4950 - val_accuracy: 0.8194
# Epoch 4/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.4694 - accuracy: 0.8243 - val_loss: 0.4651 - val_accuracy: 0.8281
# Epoch 5/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.4176 - accuracy: 0.8453 - val_loss: 0.3868 - val_accuracy: 0.8585
# Epoch 6/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.3836 - accuracy: 0.8572 - val_loss: 0.4858 - val_accuracy: 0.8129
# Epoch 7/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.3595 - accuracy: 0.8649 - val_loss: 0.3943 - val_accuracy: 0.8489
# Epoch 8/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.3338 - accuracy: 0.8737 - val_loss: 0.4089 - val_accuracy: 0.8499
# Epoch 9/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.3109 - accuracy: 0.8828 - val_loss: 0.3478 - val_accuracy: 0.8744
# Epoch 10/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.2960 - accuracy: 0.8871 - val_loss: 0.3754 - val_accuracy: 0.8606
# Epoch 11/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.2797 - accuracy: 0.8935 - val_loss: 0.3158 - val_accuracy: 0.8852
# Epoch 12/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.2649 - accuracy: 0.8989 - val_loss: 0.3302 - val_accuracy: 0.8837
# Epoch 13/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.2478 - accuracy: 0.9039 - val_loss: 0.3276 - val_accuracy: 0.8820
# Epoch 14/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.2407 - accuracy: 0.9077 - val_loss: 0.3408 - val_accuracy: 0.8816
# Epoch 15/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.2269 - accuracy: 0.9139 - val_loss: 0.3252 - val_accuracy: 0.8829
# Epoch 16/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.2170 - accuracy: 0.9163 - val_loss: 0.3302 - val_accuracy: 0.8829
# Epoch 17/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.2050 - accuracy: 0.9216 - val_loss: 0.3139 - val_accuracy: 0.8878
# Epoch 18/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.1929 - accuracy: 0.9272 - val_loss: 0.3357 - val_accuracy: 0.8761
# Epoch 19/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.1894 - accuracy: 0.9293 - val_loss: 0.3278 - val_accuracy: 0.8865
# Epoch 20/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.1757 - accuracy: 0.9332 - val_loss: 0.3504 - val_accuracy: 0.8754
# Epoch 21/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.1720 - accuracy: 0.9350 - val_loss: 0.2804 - val_accuracy: 0.9034
# Epoch 22/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.1593 - accuracy: 0.9387 - val_loss: 0.3086 - val_accuracy: 0.8977
# Epoch 23/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.1516 - accuracy: 0.9420 - val_loss: 0.3008 - val_accuracy: 0.9019
# Epoch 24/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.1462 - accuracy: 0.9453 - val_loss: 0.2924 - val_accuracy: 0.9034
# Epoch 25/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.1359 - accuracy: 0.9488 - val_loss: 0.2964 - val_accuracy: 0.9002
# Epoch 26/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.
200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0274 - accuracy: 0.9918 - val_loss: 0.4897 - val_accuracy: 0.9088
# Epoch 60/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0158 - accuracy: 0.9956 - val_loss: 0.5428 - val_accuracy: 0.8987
# Epoch 61/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0243 - accuracy: 0.9923 - val_loss: 0.5084 - val_accuracy: 0.9143
# Epoch 62/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0255 - accuracy: 0.9940 - val_loss: 0.5062 - val_accuracy: 0.9113
# Epoch 63/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0140 - accuracy: 0.9960 - val_loss: 0.5603 - val_accuracy: 0.9112
# Epoch 64/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0196 - accuracy: 0.9937 - val_loss: 0.6210 - val_accuracy: 0.8972
# Epoch 65/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0296 - accuracy: 0.9912 - val_loss: 0.4918 - val_accuracy: 0.9077
# Epoch 66/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0109 - accuracy: 0.9972 - val_loss: 0.5548 - val_accuracy: 0.9056
# Epoch 67/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0236 - accuracy: 0.9931 - val_loss: 0.5320 - val_accuracy: 0.9129
# Epoch 68/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0209 - accuracy: 0.9942 - val_loss: 0.5490 - val_accuracy: 0.9093
# Epoch 69/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0047 - accuracy: 0.9991 - val_loss: 0.7708 - val_accuracy: 0.8837
# Epoch 70/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0154 - accuracy: 0.9959 - val_loss: 0.6394 - val_accuracy: 0.9071
# Epoch 71/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0286 - accuracy: 0.9922 - val_loss: 0.5199 - val_accuracy: 0.9132
# Epoch 72/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0216 - accuracy: 0.9940 - val_loss: 0.5467 - val_accuracy: 0.9120
# Epoch 73/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0144 - accuracy: 0.9961 - val_loss: 0.5750 - val_accuracy: 0.9008
# Epoch 74/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0128 - accuracy: 0.9968 - val_loss: 0.6339 - val_accuracy: 0.8989
# Epoch 75/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0045 - accuracy: 0.9991 - val_loss: 0.6420 - val_accuracy: 0.9091
# Epoch 76/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0152 - accuracy: 0.9961 - val_loss: 0.6139 - val_accuracy: 0.9133
# Epoch 77/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0218 - accuracy: 0.9943 - val_loss: 0.6188 - val_accuracy: 0.9132
# Epoch 78/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0053 - accuracy: 0.9984 - val_loss: 0.6546 - val_accuracy: 0.9137
# Epoch 79/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0252 - accuracy: 0.9948 - val_loss: 0.6136 - val_accuracy: 0.9152
# Epoch 80/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0232 - accuracy: 0.9934 - val_loss: 0.5993 - val_accuracy: 0.9135
# Epoch 81/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0088 - accuracy: 0.9982 - val_loss: 0.6362 - val_accuracy: 0.8949
# Epoch 82/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.6575 - val_accuracy: 0.9147
# Epoch 83/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0278 - accuracy: 0.9933 - val_loss: 0.6161 - val_accuracy: 0.9126
# Epoch 84/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0125 - accuracy: 0.9962 - val_loss: 0.6313 - val_accuracy: 0.9100
# Epoch 85/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0013 - accuracy: 0.9999 - val_loss: 0.6847 - val_accuracy: 0.9136
# Epoch 86/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0239 - accuracy: 0.9945 - val_loss: 0.6616 - val_accuracy: 0.9147
# Epoch 87/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0204 - accuracy: 0.9948 - val_loss: 0.6423 - val_accuracy: 0.9126
# Epoch 88/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 8.4843e-04 - accuracy: 0.9999 - val_loss: 0.6928 - val_accuracy: 0.9142
# Epoch 89/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0232 - accuracy: 0.9942 - val_loss: 0.6655 - val_accuracy: 0.9143
# Epoch 90/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0019 - accuracy: 0.9998 - val_loss: 0.7904 - val_accuracy: 0.8940
# Epoch 91/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0156 - accuracy: 0.9960 - val_loss: 0.6928 - val_accuracy: 0.9141
# Epoch 92/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0198 - accuracy: 0.9950 - val_loss: 0.6548 - val_accuracy: 0.9149
# Epoch 93/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 7.4735e-04 - accuracy: 1.0000 - val_loss: 0.6946 - val_accuracy: 0.9151
# Epoch 94/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0207 - accuracy: 0.9952 - val_loss: 0.6650 - val_accuracy: 0.9150
# Epoch 95/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 4.3388e-04 - accuracy: 1.0000 - val_loss: 0.7185 - val_accuracy: 0.9105
# Epoch 96/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0234 - accuracy: 0.9946 - val_loss: 0.6860 - val_accuracy: 0.9153
# Epoch 97/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 1.2005 - val_accuracy: 0.8773
# Epoch 98/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0233 - accuracy: 0.9952 - val_loss: 0.7006 - val_accuracy: 0.9141
# Epoch 99/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0200 - accuracy: 0.9954 - val_loss: 0.6951 - val_accuracy: 0.9107
# Epoch 100/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0015 - accuracy: 0.9998 - val_loss: 0.7141 - val_accuracy: 0.9126
# Epoch 101/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0233 - accuracy: 0.9949 - val_loss: 0.6584 - val_accuracy: 0.9111
# Epoch 102/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 9.7228e-04 - accuracy: 0.9999 - val_loss: 0.7385 - val_accuracy: 0.9134
# Epoch 103/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0180 - accuracy: 0.9953 - val_loss: 0.7014 - val_accuracy: 0.9099
# Epoch 104/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 4.7274e-04 - accuracy: 1.0000 - val_loss: 0.7351 - val_accuracy: 0.9144
# Epoch 105/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0240 - accuracy: 0.9951 - val_loss: 0.6715 - val_accuracy: 0.9115
# Epoch 106/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 6.7982e-04 - accuracy: 0.9999 - val_loss: 0.7342 - val_accuracy: 0.9135
# Epoch 107/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 1.5596e-04 - accuracy: 1.0000 - val_loss: 0.7738 - val_accuracy: 0.9141
# Epoch 108/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0290 - accuracy: 0.9943 - val_loss: 0.7301 - val_accuracy: 0.9140
# Epoch 109/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0040 - accuracy: 0.9992 - val_loss: 0.7674 - val_accuracy: 0.8984
# Epoch 110/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0090 - accuracy: 0.9974 - val_loss: 0.7534 - val_accuracy: 0.9090
# Epoch 111/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0117 - accuracy: 0.9967 - val_loss: 0.7596 - val_accuracy: 0.9134
# Epoch 112/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0019 - accuracy: 0.9997 - val_loss: 1.2710 - val_accuracy: 0.8755
# Epoch 113/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0153 - accuracy: 0.9967 - val_loss: 0.7586 - val_accuracy: 0.9145
# Epoch 114/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 2.1425e-04 - accuracy: 1.0000 - val_loss: 0.7981 - val_accuracy: 0.9154
# Epoch 115/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0351 - accuracy: 0.9934 - val_loss: 0.7182 - val_accuracy: 0.9121
# Epoch 116/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 5.9177e-04 - accuracy: 0.9999 - val_loss: 0.7659 - val_accuracy: 0.9145
# Epoch 117/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 1.2858e-04 - accuracy: 1.0000 - val_loss: 0.8108 - val_accuracy: 0.9161
# Epoch 118/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0446 - accuracy: 0.9930 - val_loss: 0.7356 - val_accuracy: 0.9118
# Epoch 119/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 4.0383e-04 - accuracy: 1.0000 - val_loss: 0.7800 - val_accuracy: 0.9140
# Epoch 120/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 9.6112e-05 - accuracy: 1.0000 - val_loss: 0.8238 - val_accuracy: 0.9135
# Epoch 121/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0291 - accuracy: 0.9944 - val_loss: 0.7599 - val_accuracy: 0.9107
# Epoch 122/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 4.9521e-04 - accuracy: 1.0000 - val_loss: 0.7965 - val_accuracy: 0.9138
# Epoch 123/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 8.3442e-05 - accuracy: 1.0000 - val_loss: 0.8408 - val_accuracy: 0.9137
# Epoch 124/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0366 - accuracy: 0.9945 - val_loss: 0.7736 - val_accuracy: 0.9108
# Epoch 125/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 4.1440e-04 - accuracy: 0.9999 - val_loss: 0.8885 - val_accuracy: 0.9030
# Epoch 126/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0240 - accuracy: 0.9954 - val_loss: 0.8086 - val_accuracy: 0.9139
# Epoch 127/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 1.5283e-04 - accuracy: 1.0000 - val_loss: 0.8286 - val_accuracy: 0.9150
# Epoch 128/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0172 - accuracy: 0.9964 - val_loss: 0.8105 - val_accuracy: 0.9119
# Epoch 129/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 1.3070e-04 - accuracy: 1.0000 - val_loss: 0.8416 - val_accuracy: 0.9139
# Epoch 130/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0596 - accuracy: 0.9923 - val_loss: 0.7691 - val_accuracy: 0.9044
# Epoch 131/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.7756 - val_accuracy: 0.9106
# Epoch 132/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 1.8308e-04 - accuracy: 1.0000 - val_loss: 0.8149 - val_accuracy: 0.9123
# Epoch 133/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 6.3258e-05 - accuracy: 1.0000 - val_loss: 0.8660 - val_accuracy: 0.9139
# Epoch 134/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0336 - accuracy: 0.9944 - val_loss: 0.8135 - val_accuracy: 0.9101
# Epoch 135/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 2.6579e-04 - accuracy: 1.0000 - val_loss: 0.8676 - val_accuracy: 0.9133
# Epoch 136/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0365 - accuracy: 0.9937 - val_loss: 0.8018 - val_accuracy: 0.9119
# Epoch 137/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 3.5797e-04 - accuracy: 1.0000 - val_loss: 0.8424 - val_accuracy: 0.9118
# Epoch 138/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0245 - accuracy: 0.9954 - val_loss: 0.8266 - val_accuracy: 0.9041
# Epoch 139/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.8310 - val_accuracy: 0.9123
# Epoch 140/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 1.0374e-04 - accuracy: 1.0000 - val_loss: 0.8766 - val_accuracy: 0.9130
# Epoch 141/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 0.0257 - accuracy: 0.9953 - val_loss: 0.8228 - val_accuracy: 0.9103
# Epoch 142/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 7.2356e-04 - accuracy: 0.9998 - val_loss: 0.8500 - val_accuracy: 0.9117
# Epoch 143/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 6.5493e-05 - accuracy: 1.0000 - val_loss: 0.9024 - val_accuracy: 0.9148
# Epoch 144/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0195 - accuracy: 0.9962 - val_loss: 0.8527 - val_accuracy: 0.9131
# Epoch 145/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 8.1891e-04 - accuracy: 0.9998 - val_loss: 0.8976 - val_accuracy: 0.9120
# Epoch 146/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0268 - accuracy: 0.9966 - val_loss: 0.9063 - val_accuracy: 0.8984
# Epoch 147/200
# 60000/60000 [==============================] - 11s 189us/step - loss: 0.0036 - accuracy: 0.9991 - val_loss: 0.8388 - val_accuracy: 0.9126
# Epoch 148/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 8.3547e-05 - accuracy: 1.0000 - val_loss: 0.8722 - val_accuracy: 0.9139
# Epoch 149/200
# 60000/60000 [==============================] - 11s 190us/step - loss: 3.6804e-05 - accuracy: 1.0000 - val_loss: 1.0758 - val_accuracy: 0.9031
# Epoch 150/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0359 - accuracy: 0.9936 - val_loss: 0.8512 - val_accuracy: 0.9112
# Epoch 151/200
# 60000/60000 [==============================] - 12s 192us/step - loss: 9.4620e-05 - accuracy: 1.0000 - val_loss: 0.8952 - val_accuracy: 0.9127
# Epoch 152/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 3.6210e-05 - accuracy: 1.0000 - val_loss: 0.9476 - val_accuracy: 0.9134
# Epoch 153/200
# 60000/60000 [==============================] - 11s 192us/step - loss: 0.0287 - accuracy: 0.9944 - val_loss: 0.8571 - val_accuracy: 0.9107
# Epoch 154/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0170 - accuracy: 0.9959 - val_loss: 0.8650 - val_accuracy: 0.9050
# Epoch 155/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.8781 - val_accuracy: 0.9118
# Epoch 156/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0147 - accuracy: 0.9972 - val_loss: 0.8563 - val_accuracy: 0.9113
# Epoch 157/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 9.2254e-05 - accuracy: 1.0000 - val_loss: 0.8966 - val_accuracy: 0.9125
# Epoch 158/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0269 - accuracy: 0.9950 - val_loss: 0.8252 - val_accuracy: 0.9101
# Epoch 159/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 5.5684e-04 - accuracy: 0.9999 - val_loss: 0.8727 - val_accuracy: 0.9132
# Epoch 160/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 6.0696e-05 - accuracy: 1.0000 - val_loss: 0.9114 - val_accuracy: 0.9140
# Epoch 161/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.
200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0303 - accuracy: 0.9955 - val_loss: 0.9750 - val_accuracy: 0.9076
# Epoch 194/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.9855 - val_accuracy: 0.9120
# Epoch 195/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 4.4570e-05 - accuracy: 1.0000 - val_loss: 1.0169 - val_accuracy: 0.9128
# Epoch 196/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 1.5383e-05 - accuracy: 1.0000 - val_loss: 1.0603 - val_accuracy: 0.9131
# Epoch 197/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 0.0277 - accuracy: 0.9953 - val_loss: 0.9577 - val_accuracy: 0.9082
# Epoch 198/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 5.7481e-04 - accuracy: 0.9998 - val_loss: 1.0128 - val_accuracy: 0.9122
# Epoch 199/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 3.6913e-05 - accuracy: 1.0000 - val_loss: 1.0194 - val_accuracy: 0.9136
# Epoch 200/200
# 60000/60000 [==============================] - 11s 191us/step - loss: 6.1871e-04 - accuracy: 0.9999 - val_loss: 1.5749 - val_accuracy: 0.8820
# 10000/10000 [==============================] - 2s 169us/step
# Accuracy: 88.20

# %%
# Plot accuracy vs epoch

plt.figure()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy of the Trained Model')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch
# [Note] 
#  - This plot is also referred to as "Learning Curves"

plt.figure()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Loss of the Trained Model')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %% [markdown]
# Answer the following questions:
#
#
#
# 1.   What does the loss of the training set go to?
#
#   ANS: The loss of the training set gradually decreases to 0.
#
# 2.   What does the loss of the testing set go to?
#
#   ANS: The loss of the testing set initially decreases but increases after the 25th epoch.
#
# 3.   What is the reason for the discrepancy between the training and testing set loss?
#
#   ANS: The information in the training data is of two kinds: signal and noise. The signal is the part that generalizes and thus can help the model make predictions from new data. The noise is that part that is only true of the training data.
#
#   The training set loss will go down either when the model learns signal or when it learns noise. But the testing set loss will go down only when the model learns signal. So, when a model learns a signal both losses go down, but when it learns noise a gap (discrepancy) between two losses is created. Especially overfitting happens in this part, so there is almost no loss for the training set.
#
# 4.   Explain why the accuracy of the testing set, after training, differs so much from the testing set regardless of achieving high training accuracy. Name two ways to avoid this.
#
#   ANS: The accuracy discrepancy between the testing set and training set is due to overfitting the training set. As we see in the plot, the accuracy of the training set is close to 1, which means the model perfectly fits the training set. However, the model fails to predict precisely the data that it hasn't seen. In other words, it does not have generalization capability to the new data.
#
#   We could handle the overfitting by applying regularization (adding a cost to the loss function for large weights) or using dropout layers (randomly remove certain features by setting them to zero).

# %% [markdown]
# #Part 3: Dropout on input layer

# %%
# Create and train model architecture
def CNN_dropout_in(x1, x2, y):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # add 30% dropout rate to the input layer
    model.add(Dropout(0.3, input_shape=(x1, x2, 1)))

    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))

    # output layer with Softmax
    model.add(Dense(y, activation='softmax'))

    return model

# Create instance of CNN model graph
CNN_dropout_in = CNN_dropout_in(28, 28, 10)

# Compile model using an appropriate loss and optimizer algorithm
CNN_dropout_in.compile(optimizer='rmsprop', 
                       loss='categorical_crossentropy', 
                       metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_3 = CNN_dropout_in.fit(data_train, labels_train, 
                               validation_data = (data_test, labels_test),
                               epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training (* 100 to make it be %)
accuracy = CNN_dropout_in.evaluate(data_test, labels_test)
print("Accuracy: {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 12s 204us/step - loss: 2.6054 - accuracy: 0.4781 - val_loss: 1.0739 - val_accuracy: 0.6252
# Epoch 2/200
# 60000/60000 [==============================] - 12s 200us/step - loss: 0.7078 - accuracy: 0.7303 - val_loss: 0.7933 - val_accuracy: 0.7225
# Epoch 3/200
# 60000/60000 [==============================] - 12s 200us/step - loss: 0.6146 - accuracy: 0.7651 - val_loss: 0.6974 - val_accuracy: 0.7500
# Epoch 4/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0
200
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.0714 - accuracy: 0.9736 - val_loss: 0.5421 - val_accuracy: 0.8822
# Epoch 189/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0694 - accuracy: 0.9735 - val_loss: 0.5434 - val_accuracy: 0.8873
# Epoch 190/200
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.0693 - accuracy: 0.9750 - val_loss: 0.5461 - val_accuracy: 0.8789
# Epoch 191/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0693 - accuracy: 0.9746 - val_loss: 0.5493 - val_accuracy: 0.8791
# Epoch 192/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0664 - accuracy: 0.9750 - val_loss: 0.5229 - val_accuracy: 0.8835
# Epoch 193/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0679 - accuracy: 0.9741 - val_loss: 0.5741 - val_accuracy: 0.8794
# Epoch 194/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0663 - accuracy: 0.9751 - val_loss: 0.5345 - val_accuracy: 0.8847
# Epoch 195/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0660 - accuracy: 0.9749 - val_loss: 0.5474 - val_accuracy: 0.8874
# Epoch 196/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0656 - accuracy: 0.9759 - val_loss: 0.5495 - val_accuracy: 0.8762
# Epoch 197/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0685 - accuracy: 0.9741 - val_loss: 0.5248 - val_accuracy: 0.8886
# Epoch 198/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0682 - accuracy: 0.9745 - val_loss: 0.5794 - val_accuracy: 0.8783
# Epoch 199/200
# 60000/60000 [==============================] - 12s 199us/step - loss: 0.0653 - accuracy: 0.9756 - val_loss: 0.5539 - val_accuracy: 0.8782
# Epoch 200/200
# 60000/60000 [==============================] - 12s 198us/step - loss: 0.0665 - accuracy: 0.9757 - val_loss: 0.5369 - val_accuracy: 0.8851
# 10000/10000 [==============================] - 2s 178us/step
# Accuracy: 88.51

# %%
# Plot accuracy vs epoch

plt.figure()
plt.plot(history_3.history['accuracy'])
plt.plot(history_3.history['val_accuracy'])
plt.title('Accuracy of the Trained Model')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch

plt.figure()
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('Loss of the Trained Model')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %% [markdown]
# Answer the following questions:
#
#
#
# 1.   What does the loss of the training set go to?
#
#   ANS: The loss of the training set gradually decreases to 0 *(same trend as the answer to question 1 in the part 2)*.
#
# 2.   What does the loss of the testing set go to?
#
#   ANS: The loss of the testing set initially decreases but slightly increases after then *(almost the same trend as the answer to question 2 in the part 2, but the process of increase is much more slowly)*.
#
# 3.   Why is the loss of the training set so different from the loss of the testing set regardless of using dropout?
#
#   ANS: Adding the dropout layer to the input layer reduces the number of the input and makes the input be different in each epoch. However, we add the dropout layer since we would like to create a kind of ensemble of networks instead of training in one big network. Adding the dropout layer to the input layer does not achieve our ultimate goal since the model complexity is still high.

# %% [markdown]
# #Part 4-I: Dropout on Hidden Layers

# %%
# Create and train model architecture
def CNN_dropout_hidden(x1, x2, y):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # 1st hidden layer with input
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', input_shape=(x1, x2, 1)))

    # add 30% dropout rate to the 1st hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 3rd hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))

    # output layer with Softmax
    model.add(Dense(y, activation='softmax'))

    return model

# Create instance of CNN model graph
CNN_dropout_hidden = CNN_dropout_hidden(28, 28, 10)

# Compile model using an appropriate loss and optimizer algorithm
CNN_dropout_hidden.compile(optimizer='rmsprop', 
                           loss='categorical_crossentropy', 
                           metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_4_I = CNN_dropout_hidden.fit(data_train, labels_train, 
                                     validation_data = (data_test, labels_test),
                                     epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training (* 100 to make it be %)
accuracy = CNN_dropout_hidden.evaluate(data_test, labels_test)
print("Accuracy: {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 29s 482us/step - loss: 2.3855 - accuracy: 0.5346 - val_loss: 0.8387 - val_accuracy: 0.7270
# Epoch 2/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.6439 - accuracy: 0.7561 - val_loss: 0.6081 - val_accuracy: 0.7966
# Epoch 3/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.5406 - accuracy: 0.7974 - val_loss: 0.5504 - val_accuracy: 0.8164
# Epoch 4/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0
200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0154 - accuracy: 0.9950 - val_loss: 0.5002 - val_accuracy: 0.9121
# Epoch 142/200
# 60000/60000 [==============================] - 20s 333us/step - loss: 0.0165 - accuracy: 0.9942 - val_loss: 0.5042 - val_accuracy: 0.9106
# Epoch 143/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.5157 - val_accuracy: 0.9119
# Epoch 144/200
# 60000/60000 [==============================] - 20s 335us/step - loss: 0.0192 - accuracy: 0.9937 - val_loss: 0.4779 - val_accuracy: 0.9154
# Epoch 145/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0141 - accuracy: 0.9948 - val_loss: 0.4924 - val_accuracy: 0.9104
# Epoch 146/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0167 - accuracy: 0.9945 - val_loss: 0.5189 - val_accuracy: 0.9134
# Epoch 147/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0172 - accuracy: 0.9945 - val_loss: 0.4876 - val_accuracy: 0.9165
# Epoch 148/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0143 - accuracy: 0.9950 - val_loss: 0.5413 - val_accuracy: 0.9082
# Epoch 149/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0151 - accuracy: 0.9948 - val_loss: 0.4930 - val_accuracy: 0.9127
# Epoch 150/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0185 - accuracy: 0.9941 - val_loss: 0.4633 - val_accuracy: 0.9139
# Epoch 151/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.4952 - val_accuracy: 0.9129
# Epoch 152/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0137 - accuracy: 0.9952 - val_loss: 0.5048 - val_accuracy: 0.9171
# Epoch 153/200
# 60000/60000 [==============================] - 20s 333us/step - loss: 0.0158 - accuracy: 0.9947 - val_loss: 0.5171 - val_accuracy: 0.9127
# Epoch 154/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0130 - accuracy: 0.9955 - val_loss: 0.5331 - val_accuracy: 0.9117
# Epoch 155/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0184 - accuracy: 0.9941 - val_loss: 0.5142 - val_accuracy: 0.9147
# Epoch 156/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0139 - accuracy: 0.9955 - val_loss: 0.5270 - val_accuracy: 0.9065
# Epoch 157/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0154 - accuracy: 0.9945 - val_loss: 0.5144 - val_accuracy: 0.9125
# Epoch 158/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0113 - accuracy: 0.9959 - val_loss: 0.5226 - val_accuracy: 0.9141
# Epoch 159/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.5317 - val_accuracy: 0.9145
# Epoch 160/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0156 - accuracy: 0.9947 - val_loss: 0.5316 - val_accuracy: 0.9125
# Epoch 161/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0134 - accuracy: 0.9952 - val_loss: 0.4959 - val_accuracy: 0.9151
# Epoch 162/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.5239 - val_accuracy: 0.9128
# Epoch 163/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 0.5724 - val_accuracy: 0.9072
# Epoch 164/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0149 - accuracy: 0.9949 - val_loss: 0.5881 - val_accuracy: 0.9083
# Epoch 165/200
# 60000/60000 [==============================] - 20s 333us/step - loss: 0.0165 - accuracy: 0.9951 - val_loss: 0.5121 - val_accuracy: 0.9152
# Epoch 166/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0127 - accuracy: 0.9959 - val_loss: 0.5407 - val_accuracy: 0.9127
# Epoch 167/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0141 - accuracy: 0.9954 - val_loss: 0.5251 - val_accuracy: 0.9115
# Epoch 168/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.5201 - val_accuracy: 0.9085
# Epoch 169/200
# 60000/60000 [==============================] - 20s 335us/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.5212 - val_accuracy: 0.9145
# Epoch 170/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0133 - accuracy: 0.9957 - val_loss: 0.5309 - val_accuracy: 0.9171
# Epoch 171/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0155 - accuracy: 0.9947 - val_loss: 0.5083 - val_accuracy: 0.9147
# Epoch 172/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.5311 - val_accuracy: 0.9105
# Epoch 173/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0159 - accuracy: 0.9949 - val_loss: 0.5251 - val_accuracy: 0.9143
# Epoch 174/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0123 - accuracy: 0.9955 - val_loss: 0.5346 - val_accuracy: 0.9117
# Epoch 175/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0124 - accuracy: 0.9961 - val_loss: 0.5327 - val_accuracy: 0.9146
# Epoch 176/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0132 - accuracy: 0.9955 - val_loss: 0.5146 - val_accuracy: 0.9130
# Epoch 177/200
# 60000/60000 [==============================] - 20s 333us/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.5371 - val_accuracy: 0.9137
# Epoch 178/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.5475 - val_accuracy: 0.9110
# Epoch 179/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0122 - accuracy: 0.9958 - val_loss: 0.5420 - val_accuracy: 0.9149
# Epoch 180/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.5769 - val_accuracy: 0.9061
# Epoch 181/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.5555 - val_accuracy: 0.9111
# Epoch 182/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.5538 - val_accuracy: 0.9098
# Epoch 183/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0143 - accuracy: 0.9954 - val_loss: 0.5375 - val_accuracy: 0.9131
# Epoch 184/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0116 - accuracy: 0.9961 - val_loss: 0.5704 - val_accuracy: 0.9095
# Epoch 185/200
# 60000/60000 [==============================] - 20s 333us/step - loss: 0.0111 - accuracy: 0.9961 - val_loss: 0.5445 - val_accuracy: 0.9158
# Epoch 186/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.5533 - val_accuracy: 0.9145
# Epoch 187/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.5674 - val_accuracy: 0.9148
# Epoch 188/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.5488 - val_accuracy: 0.9142
# Epoch 189/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0136 - accuracy: 0.9956 - val_loss: 0.5324 - val_accuracy: 0.9143
# Epoch 190/200
# 60000/60000 [==============================] - 20s 333us/step - loss: 0.0104 - accuracy: 0.9965 - val_loss: 0.5420 - val_accuracy: 0.9187
# Epoch 191/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0114 - accuracy: 0.9962 - val_loss: 0.5524 - val_accuracy: 0.9178
# Epoch 192/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 0.5555 - val_accuracy: 0.9160
# Epoch 193/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0103 - accuracy: 0.9963 - val_loss: 0.5875 - val_accuracy: 0.9110
# Epoch 194/200
# 60000/60000 [==============================] - 20s 333us/step - loss: 0.0134 - accuracy: 0.9959 - val_loss: 0.5856 - val_accuracy: 0.9120
# Epoch 195/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0110 - accuracy: 0.9963 - val_loss: 0.5780 - val_accuracy: 0.9161
# Epoch 196/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0119 - accuracy: 0.9959 - val_loss: 0.5741 - val_accuracy: 0.9129
# Epoch 197/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.5891 - val_accuracy: 0.9099
# Epoch 198/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0106 - accuracy: 0.9966 - val_loss: 0.5726 - val_accuracy: 0.9140
# Epoch 199/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0140 - accuracy: 0.9953 - val_loss: 0.5803 - val_accuracy: 0.9120
# Epoch 200/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0126 - accuracy: 0.9955 - val_loss: 0.5713 - val_accuracy: 0.9114
# 10000/10000 [==============================] - 2s 179us/step
# Accuracy: 91.14

# %%
# Plot accuracy vs epoch

plt.figure()
plt.plot(history_4_I.history['accuracy'])
plt.plot(history_4_I.history['val_accuracy'])
plt.title('Accuracy of the Trained Model')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch

plt.figure()
plt.plot(history_4_I.history['loss'])
plt.plot(history_4_I.history['val_loss'])
plt.title('Loss of the Trained Model')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %% [markdown]
# Answer the following questions:
#
#
#
# 1.   What does the loss of the training set go to?
#
#   ANS: The loss of the training set gradually decreases to 0 *(same trend as the answer to question 1 in the part 2)*.
#
# 2.   What does the loss of the testing set go to?
#
#   ANS: The loss of the testing set initially decreases but slightly increases after then *(same trend as the answer to question 2 in the part 3)*.
#
# 3.   Why was using dropout more effective here in comparison to the architecture in Part 3?
#
#   ANS: Adding the dropout layer to the hidden layers can concretely help us randomly deactivated a certain number of neurons, thus avoiding the network learning the spurious patterns and creating an ensemble of networks. In short, it helps us reduce the model complexity.
#
# 4.   What is the difference in accuracy, after training, between the training and testing set? Is the model a good fit for the data?
#
#   ANS: The trained model almost work perfectly on the training set (accuracy \~100%). Also, the accuracy of the trained model on the testing set is quite good (\~ 90%).
#
#   I'd say the model is a good fit for the data.

# %% [markdown]
# #Part 4-II [Sub-Question 5]: Dropout on Input and Hidden Layers

# %%
# Create and train model architecture
def CNN_dropout_both(x1, x2, y):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # add 30% dropout rate to the input layer
    model.add(Dropout(0.3, input_shape=(x1, x2, 1)))

    # 1st hidden layer with input
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 1st hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 3rd hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))

    # output layer with Softmax
    model.add(Dense(y, activation='softmax'))

    return model

# Create instance of CNN model graph
CNN_dropout_both = CNN_dropout_both(28, 28, 10)

# Compile model using an appropriate loss and optimizer algorithm
CNN_dropout_both.compile(optimizer='rmsprop', 
                         loss='categorical_crossentropy', 
                         metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_4_II = CNN_dropout_both.fit(data_train, labels_train, 
                                    validation_data = (data_test, labels_test),
                                    epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training (* 100 to make it be %)
accuracy = CNN_dropout_both.evaluate(data_test, labels_test)
print("Accuracy: {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 21s 344us/step - loss: 4.6871 - accuracy: 0.4674 - val_loss: 1.2341 - val_accuracy: 0.6387
# Epoch 2/200
# 60000/60000 [==============================] - 20s 339us/step - loss: 0.7904 - accuracy: 0.7001 - val_loss: 0.9686 - val_accuracy: 0.7490
# Epoch 3/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.6658 - accuracy: 0.7441 - val_loss: 0.8767 - val_accuracy: 0.7418
# Epoch 4/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.6058 - accuracy: 0.7676 - val_loss: 0.7427 - val_accuracy: 0.7776
# Epoch 5/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.5560 - accuracy: 0.7872 - val_loss: 0.7080 - val_accuracy: 0.8009
# Epoch 6/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.5154 - accuracy: 0.8015 - val_loss: 0.7805 - val_accuracy: 0.7677
# Epoch 7/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.4801 - accuracy: 0.8146 - val_loss: 0.7072 - val_accuracy: 0.8029
# Epoch 8/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.4592 - accuracy: 0.8237 - val_loss: 0.6242 - val_accuracy: 0.8261
# Epoch 9/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.4462 - accuracy: 0.8304 - val_loss: 0.6167 - val_accuracy: 0.8279
# Epoch 10/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.4204 - accuracy: 0.8387 - val_loss: 0.5892 - val_accuracy: 0.8322
# Epoch 11/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0
200
# 60000/60000 [==============================] - 20s 340us/step - loss: 0.1182 - accuracy: 0.9542 - val_loss: 0.3920 - val_accuracy: 0.8723
# Epoch 195/200
# 60000/60000 [==============================] - 20s 339us/step - loss: 0.1175 - accuracy: 0.9552 - val_loss: 0.3963 - val_accuracy: 0.8741
# Epoch 196/200
# 60000/60000 [==============================] - 20s 340us/step - loss: 0.1163 - accuracy: 0.9545 - val_loss: 0.3859 - val_accuracy: 0.8783
# Epoch 197/200
# 60000/60000 [==============================] - 20s 339us/step - loss: 0.1173 - accuracy: 0.9540 - val_loss: 0.4087 - val_accuracy: 0.8739
# Epoch 198/200
# 60000/60000 [==============================] - 20s 339us/step - loss: 0.1154 - accuracy: 0.9545 - val_loss: 0.3888 - val_accuracy: 0.8796
# Epoch 199/200
# 60000/60000 [==============================] - 20s 340us/step - loss: 0.1159 - accuracy: 0.9551 - val_loss: 0.3996 - val_accuracy: 0.8749
# Epoch 200/200
# 60000/60000 [==============================] - 20s 340us/step - loss: 0.1159 - accuracy: 0.9550 - val_loss: 0.3898 - val_accuracy: 0.8794
# 10000/10000 [==============================] - 2s 186us/step
# Accuracy: 87.94

# %%
# Plot accuracy vs epoch

plt.figure()
plt.plot(history_4_II.history['accuracy'])
plt.plot(history_4_II.history['val_accuracy'])
plt.title('Accuracy of the Trained Model')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch

plt.figure()
plt.plot(history_4_II.history['loss'])
plt.plot(history_4_II.history['val_loss'])
plt.title('Loss of the Trained Model')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %% [markdown]
# Answer the following questions:
#
# 1.   What does the loss of the training set go to?
#
#   ANS: The loss of the training set gradually decreases close to 0.
#
# 2.   What does the loss of the testing set go to?
#
#   ANS: The loss of the testing set decreases at first, then tends to be flat till the end *(though if we draw a straight line on the plot, it seems to be a slightly increasing tendency)*. Besides, the loss of the testing set in this part gets much closer to the loss of the training set.
#
# 3.   What is the difference in accuracy, after training, between the training and testing set?
#
#   ANS: Similar to the answer to question 4 in part 4-I, the accuracy of the training set is higher than the accuracy of the testing set, but the difference between the two accuracies is smaller. In other words, two accuracy curves are closer to each other.
#
# 4.   Compare results in 4 with results in 5. Comment on robustness and accuracy.
#
#   ANS: By comparing the two accuracy plots between the part 4-I and 4-II, we could find out that the accuracy in this part (part 5) has not been improved. Thus there is also no improvement in the model robustness. I'd say two metrics (robustness and accuracy) between two parts are at the same level.

# %% [markdown]
# #Part 5 : Activation Functions

# %%
# Create and train model architecture
def CNN_dropout_both_act(x1, x2, y):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # 1st hidden layer with input
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', input_shape=(x1, x2, 1)))

    # add 30% dropout rate to the 1st hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 3rd hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))

    # output layer with Sigmoid
    model.add(Dense(y, activation='sigmoid'))

    return model

# Create instance of CNN model graph
CNN_dropout_both_act_sigmoid = CNN_dropout_both_act(28, 28, 10)

# Compile model using an appropriate loss and optimizer algorithm
CNN_dropout_both_act_sigmoid.compile(optimizer='rmsprop', 
                                     loss='categorical_crossentropy', 
                                     metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_5_1 = CNN_dropout_both_act_sigmoid.fit(data_train, labels_train, 
                                               validation_data = (data_test, labels_test),
                                               epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training 
accuracy = CNN_dropout_both_act_sigmoid.evaluate(data_test, labels_test)
print("Accuracy (sigmoid): {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 2.9474 - accuracy: 0.1358 - val_loss: 2.1437 - val_accuracy: 0.2158
# Epoch 2/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 1.9044 - accuracy: 0.2278 - val_loss: 1.6370 - val_accuracy: 0.5084
# Epoch 3/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 1.2621 - accuracy: 0.4929 - val_loss: 0.9788 - val_accuracy: 0.5828
# Epoch 4/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.7936 - accuracy: 0.6484 - val_loss: 0.8005 - val_accuracy: 0.6727
# Epoch 5/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.6399 - accuracy: 0.7126 - val_loss: 0.5975 - val_accuracy: 0.7858
# Epoch 6/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0
200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0140 - accuracy: 0.9955 - val_loss: 0.4536 - val_accuracy: 0.9175
# Epoch 179/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0121 - accuracy: 0.9957 - val_loss: 0.5097 - val_accuracy: 0.9101
# Epoch 180/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0164 - accuracy: 0.9943 - val_loss: 0.4975 - val_accuracy: 0.9124
# Epoch 181/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0132 - accuracy: 0.9952 - val_loss: 0.4977 - val_accuracy: 0.9116
# Epoch 182/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0129 - accuracy: 0.9955 - val_loss: 0.4810 - val_accuracy: 0.9109
# Epoch 183/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0142 - accuracy: 0.9951 - val_loss: 0.5190 - val_accuracy: 0.9119
# Epoch 184/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0161 - accuracy: 0.9947 - val_loss: 0.4700 - val_accuracy: 0.9147
# Epoch 185/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0119 - accuracy: 0.9953 - val_loss: 0.4859 - val_accuracy: 0.9143
# Epoch 186/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0160 - accuracy: 0.9949 - val_loss: 0.4713 - val_accuracy: 0.9159
# Epoch 187/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0119 - accuracy: 0.9960 - val_loss: 0.4576 - val_accuracy: 0.9131
# Epoch 188/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0124 - accuracy: 0.9957 - val_loss: 0.4812 - val_accuracy: 0.9121
# Epoch 189/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.5209 - val_accuracy: 0.9093
# Epoch 190/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0128 - accuracy: 0.9955 - val_loss: 0.5298 - val_accuracy: 0.9103
# Epoch 191/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0126 - accuracy: 0.9956 - val_loss: 0.5017 - val_accuracy: 0.9157
# Epoch 192/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0139 - accuracy: 0.9953 - val_loss: 0.5212 - val_accuracy: 0.9129
# Epoch 193/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0120 - accuracy: 0.9958 - val_loss: 0.4850 - val_accuracy: 0.9170
# Epoch 194/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0131 - accuracy: 0.9958 - val_loss: 0.4763 - val_accuracy: 0.9143
# Epoch 195/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.4946 - val_accuracy: 0.9125
# Epoch 196/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0106 - accuracy: 0.9963 - val_loss: 0.5467 - val_accuracy: 0.9059
# Epoch 197/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0131 - accuracy: 0.9953 - val_loss: 0.5136 - val_accuracy: 0.9113
# Epoch 198/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.0122 - accuracy: 0.9954 - val_loss: 0.5135 - val_accuracy: 0.9117
# Epoch 199/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0138 - accuracy: 0.9954 - val_loss: 0.5112 - val_accuracy: 0.9133
# Epoch 200/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0117 - accuracy: 0.9962 - val_loss: 0.4932 - val_accuracy: 0.9171
# 10000/10000 [==============================] - 2s 160us/step
# Accuracy (sigmoid): 91.71

# %%
# Plot accuracy vs epoch
#  - use 'sigmoid' activation function for the output layer

plt.figure()
plt.plot(history_5_1.history['accuracy'])
plt.plot(history_5_1.history['val_accuracy'])
plt.title('Accuracy of the Trained Model (sigmoid for output)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch
#  - use 'sigmoid' activation function for the output layer

plt.figure()
plt.plot(history_5_1.history['loss'])
plt.plot(history_5_1.history['val_loss'])
plt.title('Loss of the Trained Model (sigmoid for output)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Create and train model architecture
def CNN_dropout_both_act(x1, x2, y, activationFunc):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # 1st hidden layer with input
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', input_shape=(x1, x2, 1)))

    # add 30% dropout rate to the 1st hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 3rd hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))

    # output layer with Softmax
    model.add(Dense(y, activation=activationFunc))

    return model


# Create instance of CNN model graph
CNN_dropout_both_act_tanh_1  = CNN_dropout_both_act(28, 28, 10, 'tanh')

# Compile model using an appropriate loss and optimizer algorithm
CNN_dropout_both_act_tanh_1.compile(optimizer='rmsprop', 
                                    loss='categorical_crossentropy', 
                                    metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_5_2 = CNN_dropout_both_act_tanh_1.fit(data_train, labels_train, 
                                              validation_data = (data_test, labels_test),
                                              epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training 
accuracy = CNN_dropout_both_act_tanh_1.evaluate(data_test, labels_test)
print("Accuracy (tanh): {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 20s 325us/step - loss: 5.9744 - accuracy: 0.0998 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 2/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8182 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 3/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 4/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 5/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 6/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 7/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 8/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 9/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 10/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 11/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 12/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 13/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 14/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 15/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 16/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 17/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 18/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 19/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8094 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 20/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 21/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 22/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 23/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 24/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 25/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 26/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 27/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 28/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 29/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 30/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 31/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 32/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 33/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 34/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 35/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 36/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 37/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 38/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 39/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 40/200
# 60000/60000 [==============================] - 19s 322us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 41/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 42/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 43/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 44/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 45/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 46/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 47/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 48/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 49/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 50/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 51/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 52/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 53/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 54/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 55/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 56/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 57/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 58/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 59/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 60/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 61/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 62/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 63/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 64/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 65/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 66/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 67/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 68/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 69/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 70/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 71/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 72/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 73/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 74/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 75/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 76/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 77/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 78/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 79/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 80/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 81/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 82/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 83/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 84/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 85/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 86/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 87/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 88/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 89/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 90/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 91/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 92/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 93/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 94/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 95/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 96/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 97/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 98/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 99/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 100/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 101/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 102/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 103/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 104/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 105/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 106/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 107/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 108/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 109/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 110/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 111/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 112/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 113/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 114/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 115/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 116/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 117/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 118/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 119/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 120/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 121/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 122/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 123/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 124/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 125/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 126/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 127/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 128/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 129/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 130/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 131/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 132/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 133/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 134/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 135/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 136/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 137/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 138/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 139/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 140/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 141/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 142/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 143/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 144/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 145/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 146/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 147/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 148/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 149/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 150/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 151/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 152/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 153/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 154/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 155/200
# 60000/60000 [==============================] - 19s 319us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 156/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 157/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 158/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 159/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 160/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 161/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 162/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 163/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 164/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 165/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 166/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 167/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 168/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 169/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 170/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 171/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 172/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 173/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 174/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 175/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 176/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 177/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 178/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 179/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 180/200
# 60000/60000 [==============================] - 19s 322us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 181/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 182/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 183/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 184/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 185/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 186/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 187/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 188/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 189/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 190/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 191/200
# 60000/60000 [==============================] - 19s 322us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 192/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 193/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 194/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 195/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 196/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 197/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 198/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 199/200
# 60000/60000 [==============================] - 19s 321us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# Epoch 200/200
# 60000/60000 [==============================] - 19s 320us/step - loss: 5.8058 - accuracy: 0.1000 - val_loss: 5.8058 - val_accuracy: 0.1000
# 10000/10000 [==============================] - 2s 167us/step
# Accuracy (tanh): 10.00

# %%
# Create and train model architecture
def CNN_dropout_both_act(x1, x2, y, activationFunc):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # 1st hidden layer with input
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', input_shape=(x1, x2, 1)))

    # add 30% dropout rate to the 1st hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 3rd hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))

    # output layer with Softmax
    model.add(Dense(y, activation=activationFunc))

    return model


# Create instance of CNN model graph
CNN_dropout_both_act_tanh_2  = CNN_dropout_both_act(28, 28, 10, 'tanh')

# Compile model using an appropriate loss and optimizer algorithm
CNN_dropout_both_act_tanh_2.compile(optimizer='rmsprop', 
                                    loss='mean_squared_error', 
                                    metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_5_3 = CNN_dropout_both_act_tanh_2.fit(data_train, labels_train, 
                                              validation_data = (data_test, labels_test),
                                              epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training 
accuracy = CNN_dropout_both_act_tanh_2.evaluate(data_test, labels_test)
print("Accuracy (tanh w/ MSE loss): {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 29s 486us/step - loss: 0.9770 - accuracy: 0.1363 - val_loss: 0.0942 - val_accuracy: 0.2128
# Epoch 2/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0606 - accuracy: 0.6223 - val_loss: 0.0478 - val_accuracy: 0.7605
# Epoch 3/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0414 - accuracy: 0.7595 - val_loss: 0.0462 - val_accuracy: 0.7626
# Epoch 4/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0345 - accuracy: 0.7844 - val_loss: 0.0407 - val_accuracy: 0.7541
# Epoch 5/200
# 60000/60000 [==============================] - 20s 336us/step - loss: 0.0321 - accuracy: 0.7976 - val_loss: 0.0332 - val_accuracy: 0.7958
# Epoch 6/200
# 60000/60000 [==============================] - 20s 339us/step - loss: 0.0310 - accuracy: 0.8085 - val_loss: 0.0302 - val_accuracy: 0.8118
# Epoch 7/200
# 60000/60000 [==============================] - 20s 335us/step - loss: 0.0270 - accuracy: 0.8296 - val_loss: 0.0267 - val_accuracy: 0.8373
# Epoch 8/200
# 60000/60000 [==============================] - 20s 339us/step - loss: 0.0257 - accuracy: 0.8356 - val_loss: 0.0254 - val_accuracy: 0.8401
# Epoch 9/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.0252 - accuracy: 0.8418 - val_loss: 0.0256 - val_accuracy: 0.8409
# Epoch 10/200
# 60000/60000 [==============================] - 20s 339us/step - loss: 0.0235 - accuracy: 0.8518 - val_loss: 0.0258 - val_accuracy: 0.8409
# Epoch 11/200
# 60000/60000 [==============================] - 20s 338us/step - loss: 0.
200
# 60000/60000 [==============================] - 20s 335us/step - loss: 0.0019 - accuracy: 0.9905 - val_loss: 0.0136 - val_accuracy: 0.9173
# Epoch 192/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0017 - accuracy: 0.9912 - val_loss: 0.0140 - val_accuracy: 0.9139
# Epoch 193/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0018 - accuracy: 0.9911 - val_loss: 0.0144 - val_accuracy: 0.9107
# Epoch 194/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0017 - accuracy: 0.9916 - val_loss: 0.0138 - val_accuracy: 0.9153
# Epoch 195/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0017 - accuracy: 0.9915 - val_loss: 0.0137 - val_accuracy: 0.9171
# Epoch 196/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0017 - accuracy: 0.9916 - val_loss: 0.0138 - val_accuracy: 0.9154
# Epoch 197/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0016 - accuracy: 0.9922 - val_loss: 0.0140 - val_accuracy: 0.9137
# Epoch 198/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0017 - accuracy: 0.9912 - val_loss: 0.0141 - val_accuracy: 0.9104
# Epoch 199/200
# 60000/60000 [==============================] - 20s 335us/step - loss: 0.0017 - accuracy: 0.9917 - val_loss: 0.0147 - val_accuracy: 0.9081
# Epoch 200/200
# 60000/60000 [==============================] - 20s 334us/step - loss: 0.0018 - accuracy: 0.9908 - val_loss: 0.0142 - val_accuracy: 0.9128
# 10000/10000 [==============================] - 2s 171us/step
# Accuracy (tanh w/ MSE loss): 91.28

# %%
# Plot accuracy vs epoch
#  - use 'tanh' activation function for the output layer
#  - use MSE loss

plt.figure()
plt.plot(history_5_3.history['accuracy'])
plt.plot(history_5_3.history['val_accuracy'])
plt.title('Accuracy of the Trained Model (tanh for output and MSE for loss)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch
#  - use 'tanh' activation function for the output layer
#  - use MSE loss

plt.figure()
plt.plot(history_5_3.history['loss'])
plt.plot(history_5_3.history['val_loss'])
plt.title('Loss of the Trained Model (tanh for output and MSE for loss)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %% [markdown]
# Answer the following questions:
#
# 1-c.   Compare the above results with softmax results (with point 5 results of Part 4-II)
#
#   ANS: The results of accuracy and loss for using sigmoid as the output layer activation function have a wider range than the softmax results.
#
#   Besides, in terms of the performance, using sigmoid as the output layer activation function is slightly better (accuracy on the testing set: 91.71) than the softmax results (accuracy on the testing set: 87.94).
#
# 2-a.   Does ‘tanh’ as output activation work with Cross-entropy loss?
#
#   ANS: No, tanh as output activation does not work with cross-entropy loss.
#
# 2-b.   Give a reason why tanh is not recommended with cross entropy loss?
#
#   ANS: The cross-entropy loss expects the inputs to be in the range of 0 to 1. However, the tanh transforms the input to values in the range -1 to 1, which the cross-entropy loss cannot handle.
#
# 2-c.   Give a reason why sigmoid does not cause problem as tanh with Cross entropy loss?
#
#   ANS: Sigmoid guarantees that the output will always be between 0 and 1, so sigmoid does not cause problems as tanh with Cross-entropy loss.

# %% [markdown]
# # Part 5 : Bonus

# %% [markdown]
# 3-a.   Change hidden units to sigmoid and tanh and report the accuracy and loss plots for the training and testing sets.

# %%
# Create and train model architecture
def CNN_bonus_sigmoid(x1, x2, y):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # 1st hidden layer with input
    model.add(Conv2D(256, (3, 3), activation='sigmoid', kernel_initializer='he_normal', input_shape=(x1, x2, 1)))

    # add 30% dropout rate to the 1st hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='sigmoid', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 3rd hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='sigmoid',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='sigmoid',kernel_initializer='he_normal'))

    # output layer with Softmax
    model.add(Dense(y, activation='softmax'))

    return model

# Create instance of CNN model graph
CNN_bonus_sigmoid = CNN_bonus_sigmoid(28, 28, 10)

# Compile model using an appropriate loss and optimizer algorithm
CNN_bonus_sigmoid.compile(optimizer='rmsprop', 
                          loss='categorical_crossentropy', 
                          metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_5_b_sigmoid = CNN_bonus_sigmoid.fit(data_train, labels_train, 
                                            validation_data = (data_test, labels_test),
                                            epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training 
accuracy = CNN_bonus_sigmoid.evaluate(data_test, labels_test)
print("Accuracy (bonus w/ sigmoid): {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 29s 479us/step - loss: 2.2282 - accuracy: 0.2000 - val_loss: 1.8755 - val_accuracy: 0.4757
# Epoch 2/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 1.4815 - accuracy: 0.5649 - val_loss: 1.2952 - val_accuracy: 0.6259
# Epoch 3/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 1.1125 - accuracy: 0.6582 - val_loss: 1.0444 - val_accuracy: 0.6774
# Epoch 4/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.9260 - accuracy: 0.6934 - val_loss: 0.8664 - val_accuracy: 0.7267
# Epoch 5/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.7995 - accuracy: 0.7212 - val_loss: 0.8069 - val_accuracy: 0.7142
# Epoch 6/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.7419 - accuracy: 0.7300 - val_loss: 0.7414 - val_accuracy: 0.7294
# Epoch 7/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.6936 - accuracy: 0.7421 - val_loss: 0.7530 - val_accuracy: 0.7207
# Epoch 8/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.6541 - accuracy: 0.7509 - val_loss: 0.7196 - val_accuracy: 0.7299
# Epoch 9/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.6228 - accuracy: 0.7621 - val_loss: 0.6598 - val_accuracy: 0.7529
# Epoch 10/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.5969 - accuracy: 0.7704 - val_loss: 0.6151 - val_accuracy: 0.7691
# Epoch 11/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.5710 - accuracy: 0.7800 - val_loss: 0.5840 - val_accuracy: 0.7711
# Epoch 12/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.5522 - accuracy: 0.7870 - val_loss: 0.5897 - val_accuracy: 0.7801
# Epoch 13/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.5313 - accuracy: 0.7951 - val_loss: 0.5644 - val_accuracy: 0.7820
# Epoch 14/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.5174 - accuracy: 0.8018 - val_loss: 0.5515 - val_accuracy: 0.7873
# Epoch 15/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.4987 - accuracy: 0.8096 - val_loss: 0.5305 - val_accuracy: 0.7973
# Epoch 16/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.4867 - accuracy: 0.8156 - val_loss: 0.5409 - val_accuracy: 0.8014
# Epoch 17/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.4774 - accuracy: 0.8195 - val_loss: 0.5283 - val_accuracy: 0.8060
# Epoch 18/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.4620 - accuracy: 0.8255 - val_loss: 0.5253 - val_accuracy: 0.7991
# Epoch 19/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.4568 - accuracy: 0.8282 - val_loss: 0.4775 - val_accuracy: 0.8181
# Epoch 20/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.4461 - accuracy: 0.8317 - val_loss: 0.5047 - val_accuracy: 0.8135
# Epoch 21/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.4385 - accuracy: 0.8346 - val_loss: 0.4821 - val_accuracy: 0.8212
# Epoch 22/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.4263 - accuracy: 0.8404 - val_loss: 0.4806 - val_accuracy: 0.8227
# Epoch 23/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.4227 - accuracy: 0.8399 - val_loss: 0.4565 - val_accuracy: 0.8305
# Epoch 24/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.4125 - accuracy: 0.8461 - val_loss: 0.4556 - val_accuracy: 0.8306
# Epoch 25/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.4071 - accuracy: 0.8471 - val_loss: 0.4544 - val_accuracy: 0.8330
# Epoch 26/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.3988 - accuracy: 0.8511 - val_loss: 0.4368 - val_accuracy: 0.8386
# Epoch 27/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.3922 - accuracy: 0.8544 - val_loss: 0.4584 - val_accuracy: 0.8297
# Epoch 28/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.3879 - accuracy: 0.8547 - val_loss: 0.4317 - val_accuracy: 0.8409
# Epoch 29/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.3832 - accuracy: 0.8578 - val_loss: 0.4263 - val_accuracy: 0.8352
# Epoch 30/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.
200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1091 - accuracy: 0.9599 - val_loss: 0.3008 - val_accuracy: 0.9004
# Epoch 183/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1094 - accuracy: 0.9590 - val_loss: 0.2903 - val_accuracy: 0.9032
# Epoch 184/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1090 - accuracy: 0.9591 - val_loss: 0.3017 - val_accuracy: 0.9018
# Epoch 185/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1078 - accuracy: 0.9594 - val_loss: 0.2930 - val_accuracy: 0.9032
# Epoch 186/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1065 - accuracy: 0.9606 - val_loss: 0.3121 - val_accuracy: 0.8984
# Epoch 187/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1074 - accuracy: 0.9606 - val_loss: 0.3088 - val_accuracy: 0.8978
# Epoch 188/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1070 - accuracy: 0.9596 - val_loss: 0.2938 - val_accuracy: 0.9035
# Epoch 189/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1034 - accuracy: 0.9615 - val_loss: 0.2894 - val_accuracy: 0.9079
# Epoch 190/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1010 - accuracy: 0.9618 - val_loss: 0.3151 - val_accuracy: 0.9011
# Epoch 191/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.1018 - accuracy: 0.9624 - val_loss: 0.3009 - val_accuracy: 0.9027
# Epoch 192/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.1018 - accuracy: 0.9621 - val_loss: 0.3009 - val_accuracy: 0.9042
# Epoch 193/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0998 - accuracy: 0.9633 - val_loss: 0.2992 - val_accuracy: 0.9033
# Epoch 194/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0992 - accuracy: 0.9629 - val_loss: 0.3185 - val_accuracy: 0.8998
# Epoch 195/200
# 60000/60000 [==============================] - 20s 329us/step - loss: 0.1011 - accuracy: 0.9628 - val_loss: 0.3036 - val_accuracy: 0.9051
# Epoch 196/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0973 - accuracy: 0.9647 - val_loss: 0.3118 - val_accuracy: 0.9025
# Epoch 197/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0993 - accuracy: 0.9621 - val_loss: 0.3178 - val_accuracy: 0.8986
# Epoch 198/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0974 - accuracy: 0.9634 - val_loss: 0.3167 - val_accuracy: 0.9008
# Epoch 199/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0956 - accuracy: 0.9653 - val_loss: 0.3030 - val_accuracy: 0.9052
# Epoch 200/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0933 - accuracy: 0.9656 - val_loss: 0.2933 - val_accuracy: 0.9055
# 10000/10000 [==============================] - 2s 169us/step
# Accuracy (bonus w/ sigmoid): 90.55

# %%
# Plot accuracy vs epoch
#  - use 'sigmoid' in hidden units
#  - use 'softmax' in output layer
#  - use 'categorical cross-entropy' loss

plt.figure()
plt.plot(history_5_b_sigmoid.history['accuracy'])
plt.plot(history_5_b_sigmoid.history['val_accuracy'])
plt.title('Accuracy of the Trained Model (sigmoid in hidden units)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch
#  - use 'sigmoid' in hidden units
#  - use 'softmax' in output layer
#  - use 'categorical cross-entropy' loss

plt.figure()
plt.plot(history_5_b_sigmoid.history['loss'])
plt.plot(history_5_b_sigmoid.history['val_loss'])
plt.title('Loss of the Trained Model (sigmoid in hidden units)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Create and train model architecture
def CNN_bonus_tanh(x1, x2, y):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # 1st hidden layer with input
    model.add(Conv2D(256, (3, 3), activation='tanh', kernel_initializer='he_normal', input_shape=(x1, x2, 1)))

    # add 30% dropout rate to the 1st hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='tanh', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 3rd hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='tanh',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='tanh',kernel_initializer='he_normal'))

    # output layer with Softmax
    model.add(Dense(y, activation='softmax'))

    return model

# Create instance of CNN model graph
CNN_bonus_tanh = CNN_bonus_tanh(28, 28, 10)

# Compile model using an appropriate loss and optimizer algorithm
CNN_bonus_tanh.compile(optimizer='rmsprop', 
                       loss='categorical_crossentropy', 
                       metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_5_b_tanh = CNN_bonus_tanh.fit(data_train, labels_train, 
                                      validation_data = (data_test, labels_test),
                                      epochs=200, batch_size=2048)

# Print accuracy of model on testing set after training 
accuracy = CNN_bonus_tanh.evaluate(data_test, labels_test)
print("Accuracy (bonus w/ tanh): {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 20s 333us/step - loss:
200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0330 - accuracy: 0.9884 - val_loss: 0.5485 - val_accuracy: 0.8763
# Epoch 191/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0350 - accuracy: 0.9875 - val_loss: 0.5634 - val_accuracy: 0.8727
# Epoch 192/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0328 - accuracy: 0.9882 - val_loss: 0.5163 - val_accuracy: 0.8823
# Epoch 193/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0350 - accuracy: 0.9873 - val_loss: 0.5627 - val_accuracy: 0.8714
# Epoch 194/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0327 - accuracy: 0.9886 - val_loss: 0.5763 - val_accuracy: 0.8711
# Epoch 195/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0359 - accuracy: 0.9867 - val_loss: 0.4940 - val_accuracy: 0.8858
# Epoch 196/200
# 60000/60000 [==============================] - 20s 330us/step - loss: 0.0333 - accuracy: 0.9881 - val_loss: 0.5533 - val_accuracy: 0.8741
# Epoch 197/200
# 60000/60000 [==============================] - 20s 332us/step - loss: 0.0349 - accuracy: 0.9876 - val_loss: 0.5301 - val_accuracy: 0.8808
# Epoch 198/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0356 - accuracy: 0.9869 - val_loss: 0.5730 - val_accuracy: 0.8735
# Epoch 199/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0355 - accuracy: 0.9875 - val_loss: 0.5309 - val_accuracy: 0.8803
# Epoch 200/200
# 60000/60000 [==============================] - 20s 331us/step - loss: 0.0335 - accuracy: 0.9881 - val_loss: 0.5223 - val_accuracy: 0.8794
# 10000/10000 [==============================] - 2s 167us/step
# Accuracy (bonus w/ tanh): 87.94

# %%
# Plot loss vs epoch
#  - use 'tanh' in hidden units
#  - use 'softmax' in output layer
#  - use 'categorical cross-entropy' loss

plt.figure()
plt.plot(history_5_b_tanh.history['accuracy'])
plt.plot(history_5_b_tanh.history['val_accuracy'])
plt.title('Accuracy of the Trained Model (tanh in hidden units)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch
#  - use 'tanh' in hidden units
#  - use 'softmax' in output layer
#  - use 'categorical cross-entropy' loss

plt.figure()
plt.plot(history_5_b_tanh.history['loss'])
plt.plot(history_5_b_tanh.history['val_loss'])
plt.title('Loss of the Trained Model (tanh in hidden units)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %% [markdown]
# 3-b.   When using ReLU hidden layer activations, compare average activity [number of active neurons] in layers during training and testing.
#
#   i.  Note 1: Choose and fix few images over which you want to calculate the average activity in the layers during training and testing.
#
#   ii.  Note 2: Choose certain epochs on which you will be calculating the activity. Doing it on every epoch will reduce your speed of training.

# %%
# [Reference Website]
#  - https://keras.io/guides/sequential_model/#feature-extraction-with-a-sequential-model
#  - https://keras.io/api/callbacks/
#  - https://keras.io/guides/writing_your_own_callbacks/
#  - https://stackoverflow.com/questions/41711190/keras-how-to-get-the-output-of-each-layer

# Create and train model architecture
def CNN_bonus_relu(x1, x2, y):
    # Easiest way to build model in Keras is using Squential. It allows models to 
    # be built layer by layer as we will do here
    model = Sequential()

    # 1st hidden layer with input
    model.add(Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', input_shape=(x1, x2, 1)))

    # add 30% dropout rate to the 1st hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal'))

    # add 30% dropout rate to the 3rd hidden layer
    model.add(Dropout(0.3))

    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Flatten())
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(100, activation='relu',kernel_initializer='he_normal'))

    # output layer with Softmax
    model.add(Dense(y, activation='softmax'))

    return model

class callback_train(keras.callbacks.Callback):
    def __init__(self, data, epoch):
        self.data = data
        self.epoch = epoch - 1

    def on_epoch_end(self, epoch, logs=None):
        if epoch == self.epoch:
            from keras import backend as K

            print('\n======================================================================================================')
            print(  '=  Average activity (number of active neurons) @ Training                                            =')
            print(  '======================================================================================================')

            inputs = self.model.input
            outputs = [layer.output for layer in self.model.layers]
            functions = [K.function([inputs], [output]) for output in outputs]
            layer_outputs = [func([self.data[:5]]) for func in functions]
            
            for i in range(len(layer_outputs)):
                layer = self.model.layers[i]
                output = layer_outputs[i]
                print('[ Layer: {0:<17} ] Output Shape: {1:<17}; Avg Activity: {2} / {3} = {4:.3f}'.format(
                    layer.name, 
                    output[0].shape, 
                    output[0].size - np.count_nonzero(output[0] == 0), 
                    output[0].size, 
                    (output[0].size - np.count_nonzero(output[0] == 0)) / float(output[0].size)
                ))

            print(  '======================================================================================================\n')

class callback_evaluate(keras.callbacks.Callback):
    def __init__(self, data):
        self.data = data

    def on_test_end(self, logs=None):
        from keras import backend as K

        print('\n======================================================================================================')
        print(  '=  Average activity (number of active neurons) @ Testing                                             =')
        print(  '======================================================================================================')

        inputs = self.model.input
        outputs = [layer.output for layer in self.model.layers]
        functions = [K.function([inputs], [output]) for output in outputs]
        layer_outputs = [func([self.data[:5]]) for func in functions]
        
        for i in range(len(layer_outputs)):
            layer = self.model.layers[i]
            output = layer_outputs[i]
            print('[ Layer: {0:<17} ] Output Shape: {1:<17}; Avg Activity: {2} / {3} = {4:.3f}'.format(
                layer.name, 
                output[0].shape, 
                output[0].size - np.count_nonzero(output[0] == 0), 
                output[0].size, 
                (output[0].size - np.count_nonzero(output[0] == 0)) / float(output[0].size)
            ))

        print(  '======================================================================================================\n')

# Create instance of CNN model graph
CNN_bonus_relu = CNN_bonus_relu(28, 28, 10)

# Compile model using an appropriate loss and optimizer algorithm
CNN_bonus_relu.compile(optimizer='rmsprop', 
                       loss='categorical_crossentropy', 
                       metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_5_b_sigmoid = CNN_bonus_relu.fit(data_train, labels_train, 
                                         validation_data = (data_test, labels_test),
                                         epochs=200, batch_size=2048,
                                         callbacks=[callback_train(data_train, 100)])

# Print accuracy of model on testing set after training 
accuracy = CNN_bonus_relu.evaluate(data_test, labels_test, 
                                   callbacks=[callback_evaluate(data_test)])
print("Accuracy (bonus w/ relu): {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/200
# 60000/60000 [==============================] - 29s 476us/step - loss: 2.9089 - accuracy: 0.5254 - val_loss: 0.8704 - val_accuracy: 0.7245
# Epoch 2/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.6454 - accuracy: 0.7560 - val_loss: 0.6954 - val_accuracy: 0.7754
# Epoch 3/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.5754 - accuracy: 0.7839 - val_loss: 0.6513 - val_accuracy: 0.7631
# Epoch 4/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.5039 - accuracy: 0.8087 - val_loss: 0.6316 - val_accuracy: 0.7863
# Epoch 5/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.4588 - accuracy: 0.8289 - val_loss: 0.4853 - val_accuracy: 0.8393
# Epoch 6/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.4236 - accuracy: 0.8420 - val_loss: 0.4126 - val_accuracy: 0.8584
# Epoch 7/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.3834 - accuracy: 0.8562 - val_loss: 0.4477 - val_accuracy: 0.8528
# Epoch 8/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.3705 - accuracy: 0.8579 - val_loss: 0.4351 - val_accuracy: 0.8400
# Epoch 9/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.3450 - accuracy: 0.8694 - val_loss: 0.3854 - val_accuracy: 0.8728
# Epoch 10/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.3234 - accuracy: 0.8781 - val_loss: 0.4484 - val_accuracy: 0.8139
# Epoch 11/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.3149 - accuracy: 0.8824 - val_loss: 0.4141 - val_accuracy: 0.8614
# Epoch 12/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0
200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0427 - accuracy: 0.9841 - val_loss: 0.3352 - val_accuracy: 0.9096
# Epoch 74/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0419 - accuracy: 0.9847 - val_loss: 0.3699 - val_accuracy: 0.9077
# Epoch 75/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0434 - accuracy: 0.9837 - val_loss: 0.4042 - val_accuracy: 0.9089
# Epoch 76/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0394 - accuracy: 0.9852 - val_loss: 0.3866 - val_accuracy: 0.9098
# Epoch 77/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0401 - accuracy: 0.9854 - val_loss: 0.3536 - val_accuracy: 0.9114
# Epoch 78/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0423 - accuracy: 0.9847 - val_loss: 0.3608 - val_accuracy: 0.9113
# Epoch 79/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0374 - accuracy: 0.9869 - val_loss: 0.3614 - val_accuracy: 0.9112
# Epoch 80/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0371 - accuracy: 0.9865 - val_loss: 0.3497 - val_accuracy: 0.9134
# Epoch 81/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0335 - accuracy: 0.9878 - val_loss: 0.3989 - val_accuracy: 0.9074
# Epoch 82/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0366 - accuracy: 0.9872 - val_loss: 0.3786 - val_accuracy: 0.9120
# Epoch 83/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0352 - accuracy: 0.9874 - val_loss: 0.3813 - val_accuracy: 0.9114
# Epoch 84/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0356 - accuracy: 0.9867 - val_loss: 0.3953 - val_accuracy: 0.9059
# Epoch 85/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0318 - accuracy: 0.9885 - val_loss: 0.3717 - val_accuracy: 0.9120
# Epoch 86/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0304 - accuracy: 0.9887 - val_loss: 0.4063 - val_accuracy: 0.9063
# Epoch 87/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0328 - accuracy: 0.9880 - val_loss: 0.4099 - val_accuracy: 0.9092
# Epoch 88/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0303 - accuracy: 0.9890 - val_loss: 0.4056 - val_accuracy: 0.9102
# Epoch 89/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0284 - accuracy: 0.9895 - val_loss: 0.4262 - val_accuracy: 0.9072
# Epoch 90/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0317 - accuracy: 0.9886 - val_loss: 0.4004 - val_accuracy: 0.9114
# Epoch 91/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0302 - accuracy: 0.9892 - val_loss: 0.3933 - val_accuracy: 0.9125
# Epoch 92/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0259 - accuracy: 0.9907 - val_loss: 0.4627 - val_accuracy: 0.8993
# Epoch 93/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0302 - accuracy: 0.9895 - val_loss: 0.3903 - val_accuracy: 0.9102
# Epoch 94/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0268 - accuracy: 0.9905 - val_loss: 0.4036 - val_accuracy: 0.9144
# Epoch 95/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0311 - accuracy: 0.9891 - val_loss: 0.4067 - val_accuracy: 0.9145
# Epoch 96/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0251 - accuracy: 0.9908 - val_loss: 0.4278 - val_accuracy: 0.9090
# Epoch 97/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0265 - accuracy: 0.9908 - val_loss: 0.4272 - val_accuracy: 0.9098
# Epoch 98/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0274 - accuracy: 0.9899 - val_loss: 0.4465 - val_accuracy: 0.9051
# Epoch 99/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0270 - accuracy: 0.9906 - val_loss: 0.4343 - val_accuracy: 0.9130
# Epoch 100/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0233 - accuracy: 0.9916 - val_loss: 0.4524 - val_accuracy: 0.9120
#
# ======================================================================================================
# =  Average activity (number of active neurons) @ Training                                            =
# ======================================================================================================
# [ Layer: conv2d_1          ] Output Shape: (5, 26, 26, 256) ; Avg Activity: 305552 / 865280 = 0.353
# [ Layer: dropout_1         ] Output Shape: (5, 26, 26, 256) ; Avg Activity: 305552 / 865280 = 0.353
# [ Layer: max_pooling2d_1   ] Output Shape: (5, 13, 13, 256) ; Avg Activity: 109706 / 216320 = 0.507
# [ Layer: conv2d_2          ] Output Shape: (5, 11, 11, 128) ; Avg Activity: 7835 / 77440 = 0.101
# [ Layer: dropout_2         ] Output Shape: (5, 11, 11, 128) ; Avg Activity: 7835 / 77440 = 0.101
# [ Layer: max_pooling2d_2   ] Output Shape: (5, 5, 5, 128)   ; Avg Activity: 3330 / 16000 = 0.208
# [ Layer: flatten_1         ] Output Shape: (5, 3200)        ; Avg Activity: 3330 / 16000 = 0.208
# [ Layer: dense_1           ] Output Shape: (5, 100)         ; Avg Activity: 160 / 500 = 0.320
# [ Layer: dense_2           ] Output Shape: (5, 100)         ; Avg Activity: 203 / 500 = 0.406
# [ Layer: dense_3           ] Output Shape: (5, 10)          ; Avg Activity: 50 / 50 = 1.000
# ======================================================================================================
#
# Epoch 101/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0254 - accuracy: 0.9911 - val_loss: 0.4370 - val_accuracy: 0.9120
# Epoch 102/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0240 - accuracy: 0.9912 - val_loss: 0.4401 - val_accuracy: 0.9135
# Epoch 103/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0262 - accuracy: 0.9911 - val_loss: 0.4418 - val_accuracy: 0.9085
# Epoch 104/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0254 - accuracy: 0.9909 - val_loss: 0.4393 - val_accuracy: 0.9086
# Epoch 105/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0226 - accuracy: 0.9918 - val_loss: 0.4451 - val_accuracy: 0.9138
# Epoch 106/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0218 - accuracy: 0.9922 - val_loss: 0.4376 - val_accuracy: 0.9026
# Epoch 107/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0219 - accuracy: 0.9919 - val_loss: 0.4612 - val_accuracy: 0.9091
# Epoch 108/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0225 - accuracy: 0.9924 - val_loss: 0.4244 - val_accuracy: 0.9082
# Epoch 109/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0241 - accuracy: 0.9918 - val_loss: 0.4689 - val_accuracy: 0.9071
# Epoch 110/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0238 - accuracy: 0.9918 - val_loss: 0.4411 - val_accuracy: 0.9120
# Epoch 111/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0233 - accuracy: 0.9920 - val_loss: 0.4498 - val_accuracy: 0.9110
# Epoch 112/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0194 - accuracy: 0.9934 - val_loss: 0.4534 - val_accuracy: 0.9052
# Epoch 113/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0231 - accuracy: 0.9919 - val_loss: 0.5016 - val_accuracy: 0.9076
# Epoch 114/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0223 - accuracy: 0.9920 - val_loss: 0.4910 - val_accuracy: 0.9067
# Epoch 115/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0205 - accuracy: 0.9927 - val_loss: 0.4794 - val_accuracy: 0.9088
# Epoch 116/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0220 - accuracy: 0.9917 - val_loss: 0.4813 - val_accuracy: 0.9084
# Epoch 117/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0201 - accuracy: 0.9927 - val_loss: 0.5477 - val_accuracy: 0.9016
# Epoch 118/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0202 - accuracy: 0.9928 - val_loss: 0.4832 - val_accuracy: 0.9095
# Epoch 119/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0171 - accuracy: 0.9938 - val_loss: 0.4801 - val_accuracy: 0.9114
# Epoch 120/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0235 - accuracy: 0.9919 - val_loss: 0.4504 - val_accuracy: 0.9106
# Epoch 121/200
# 60000/60000 [==============================] - 20s 326us/step - loss: 0.0189 - accuracy: 0.9933 - val_loss: 0.4827 - val_accuracy: 0.9072
# Epoch 122/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.4757 - val_accuracy: 0.9090
# Epoch 123/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0209 - accuracy: 0.9927 - val_loss: 0.4786 - val_accuracy: 0.9118
# Epoch 124/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0174 - accuracy: 0.9938 - val_loss: 0.4888 - val_accuracy: 0.9127
# Epoch 125/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0195 - accuracy: 0.9933 - val_loss: 0.5063 - val_accuracy: 0.9104
# Epoch 126/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0187 - accuracy: 0.9937 - val_loss: 0.4943 - val_accuracy: 0.9115
# Epoch 127/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0200 - accuracy: 0.9934 - val_loss: 0.4646 - val_accuracy: 0.9147
# Epoch 128/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0179 - accuracy: 0.9937 - val_loss: 0.4833 - val_accuracy: 0.9143
# Epoch 129/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0199 - accuracy: 0.9934 - val_loss: 0.4794 - val_accuracy: 0.9114
# Epoch 130/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0157 - accuracy: 0.9945 - val_loss: 0.5059 - val_accuracy: 0.9115
# Epoch 131/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0186 - accuracy: 0.9937 - val_loss: 0.4935 - val_accuracy: 0.9149
# Epoch 132/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0185 - accuracy: 0.9937 - val_loss: 0.4889 - val_accuracy: 0.9091
# Epoch 133/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 0.4948 - val_accuracy: 0.9087
# Epoch 134/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0168 - accuracy: 0.9940 - val_loss: 0.5414 - val_accuracy: 0.9070
# Epoch 135/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0174 - accuracy: 0.9943 - val_loss: 0.4995 - val_accuracy: 0.9078
# Epoch 136/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0158 - accuracy: 0.9944 - val_loss: 0.4963 - val_accuracy: 0.9114
# Epoch 137/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0185 - accuracy: 0.9933 - val_loss: 0.5261 - val_accuracy: 0.9103
# Epoch 138/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0160 - accuracy: 0.9947 - val_loss: 0.5105 - val_accuracy: 0.9098
# Epoch 139/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0178 - accuracy: 0.9942 - val_loss: 0.5245 - val_accuracy: 0.9127
# Epoch 140/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.4751 - val_accuracy: 0.9099
# Epoch 141/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0165 - accuracy: 0.9943 - val_loss: 0.5163 - val_accuracy: 0.9108
# Epoch 142/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0157 - accuracy: 0.9946 - val_loss: 0.5617 - val_accuracy: 0.9088
# Epoch 143/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.5185 - val_accuracy: 0.9080
# Epoch 144/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0195 - accuracy: 0.9938 - val_loss: 0.5244 - val_accuracy: 0.9165
# Epoch 145/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.5441 - val_accuracy: 0.9023
# Epoch 146/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0174 - accuracy: 0.9944 - val_loss: 0.5191 - val_accuracy: 0.9100
# Epoch 147/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0181 - accuracy: 0.9940 - val_loss: 0.5327 - val_accuracy: 0.9117
# Epoch 148/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0130 - accuracy: 0.9953 - val_loss: 0.5544 - val_accuracy: 0.9093
# Epoch 149/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0169 - accuracy: 0.9944 - val_loss: 0.5652 - val_accuracy: 0.9092
# Epoch 150/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.5433 - val_accuracy: 0.9117
# Epoch 151/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0166 - accuracy: 0.9943 - val_loss: 0.4961 - val_accuracy: 0.9099
# Epoch 152/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0121 - accuracy: 0.9961 - val_loss: 0.5219 - val_accuracy: 0.9080
# Epoch 153/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0150 - accuracy: 0.9949 - val_loss: 0.5081 - val_accuracy: 0.9147
# Epoch 154/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0153 - accuracy: 0.9947 - val_loss: 0.5405 - val_accuracy: 0.9138
# Epoch 155/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0158 - accuracy: 0.9948 - val_loss: 0.5308 - val_accuracy: 0.9125
# Epoch 156/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0144 - accuracy: 0.9952 - val_loss: 0.5782 - val_accuracy: 0.9067
# Epoch 157/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.5452 - val_accuracy: 0.9143
# Epoch 158/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0161 - accuracy: 0.9948 - val_loss: 0.5330 - val_accuracy: 0.9145
# Epoch 159/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0129 - accuracy: 0.9957 - val_loss: 0.5348 - val_accuracy: 0.9126
# Epoch 160/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0137 - accuracy: 0.9954 - val_loss: 0.5317 - val_accuracy: 0.9131
# Epoch 161/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0163 - accuracy: 0.9947 - val_loss: 0.5680 - val_accuracy: 0.9118
# Epoch 162/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0141 - accuracy: 0.9953 - val_loss: 0.5733 - val_accuracy: 0.9077
# Epoch 163/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.5071 - val_accuracy: 0.9108
# Epoch 164/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.5682 - val_accuracy: 0.9111
# Epoch 165/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0159 - accuracy: 0.9947 - val_loss: 0.5344 - val_accuracy: 0.9146
# Epoch 166/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0150 - accuracy: 0.9950 - val_loss: 0.5389 - val_accuracy: 0.9123
# Epoch 167/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.5527 - val_accuracy: 0.9152
# Epoch 168/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0134 - accuracy: 0.9955 - val_loss: 0.5427 - val_accuracy: 0.9130
# Epoch 169/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0126 - accuracy: 0.9959 - val_loss: 0.5659 - val_accuracy: 0.9126
# Epoch 170/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.5828 - val_accuracy: 0.9100
# Epoch 171/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0135 - accuracy: 0.9955 - val_loss: 0.5964 - val_accuracy: 0.9079
# Epoch 172/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0140 - accuracy: 0.9954 - val_loss: 0.5518 - val_accuracy: 0.9107
# Epoch 173/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.5541 - val_accuracy: 0.9141
# Epoch 174/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0128 - accuracy: 0.9956 - val_loss: 0.5461 - val_accuracy: 0.9116
# Epoch 175/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.5960 - val_accuracy: 0.9134
# Epoch 176/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0133 - accuracy: 0.9955 - val_loss: 0.5407 - val_accuracy: 0.9162
# Epoch 177/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0123 - accuracy: 0.9957 - val_loss: 0.5975 - val_accuracy: 0.9127
# Epoch 178/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.5788 - val_accuracy: 0.9154
# Epoch 179/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.5670 - val_accuracy: 0.9134
# Epoch 180/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0138 - accuracy: 0.9955 - val_loss: 0.5506 - val_accuracy: 0.9157
# Epoch 181/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.5551 - val_accuracy: 0.9132
# Epoch 182/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0144 - accuracy: 0.9952 - val_loss: 0.5829 - val_accuracy: 0.9127
# Epoch 183/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0134 - accuracy: 0.9958 - val_loss: 0.6427 - val_accuracy: 0.9066
# Epoch 184/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 0.5627 - val_accuracy: 0.9112
# Epoch 185/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0116 - accuracy: 0.9964 - val_loss: 0.5993 - val_accuracy: 0.9138
# Epoch 186/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0136 - accuracy: 0.9954 - val_loss: 0.5758 - val_accuracy: 0.9147
# Epoch 187/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.5667 - val_accuracy: 0.9121
# Epoch 188/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0129 - accuracy: 0.9958 - val_loss: 0.5973 - val_accuracy: 0.9141
# Epoch 189/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0149 - accuracy: 0.9952 - val_loss: 0.6138 - val_accuracy: 0.9110
# Epoch 190/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.6147 - val_accuracy: 0.9115
# Epoch 191/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0120 - accuracy: 0.9960 - val_loss: 0.5876 - val_accuracy: 0.9165
# Epoch 192/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.5922 - val_accuracy: 0.9099
# Epoch 193/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0137 - accuracy: 0.9959 - val_loss: 0.5659 - val_accuracy: 0.9138
# Epoch 194/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0139 - accuracy: 0.9956 - val_loss: 0.5907 - val_accuracy: 0.9113
# Epoch 195/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0123 - accuracy: 0.9958 - val_loss: 0.5850 - val_accuracy: 0.9151
# Epoch 196/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0123 - accuracy: 0.9959 - val_loss: 0.6100 - val_accuracy: 0.9144
# Epoch 197/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0112 - accuracy: 0.9963 - val_loss: 0.5946 - val_accuracy: 0.9101
# Epoch 198/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0103 - accuracy: 0.9965 - val_loss: 0.6101 - val_accuracy: 0.9136
# Epoch 199/200
# 60000/60000 [==============================] - 20s 328us/step - loss: 0.0138 - accuracy: 0.9956 - val_loss: 0.5900 - val_accuracy: 0.9133
# Epoch 200/200
# 60000/60000 [==============================] - 20s 327us/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.6012 - val_accuracy: 0.9136
# 10000/10000 [==============================] - 2s 195us/step
#
# ======================================================================================================
# =  Average activity (number of active neurons) @ Testing                                             =
# ======================================================================================================
# [ Layer: conv2d_1          ] Output Shape: (5, 26, 26, 256) ; Avg Activity: 301913 / 865280 = 0.349
# [ Layer: dropout_1         ] Output Shape: (5, 26, 26, 256) ; Avg Activity: 301913 / 865280 = 0.349
# [ Layer: max_pooling2d_1   ] Output Shape: (5, 13, 13, 256) ; Avg Activity: 110743 / 216320 = 0.512
# [ Layer: conv2d_2          ] Output Shape: (5, 11, 11, 128) ; Avg Activity: 7176 / 77440 = 0.093
# [ Layer: dropout_2         ] Output Shape: (5, 11, 11, 128) ; Avg Activity: 7176 / 77440 = 0.093
# [ Layer: max_pooling2d_2   ] Output Shape: (5, 5, 5, 128)   ; Avg Activity: 3033 / 16000 = 0.190
# [ Layer: flatten_1         ] Output Shape: (5, 3200)        ; Avg Activity: 3033 / 16000 = 0.190
# [ Layer: dense_1           ] Output Shape: (5, 100)         ; Avg Activity: 155 / 500 = 0.310
# [ Layer: dense_2           ] Output Shape: (5, 100)         ; Avg Activity: 191 / 500 = 0.382
# [ Layer: dense_3           ] Output Shape: (5, 10)          ; Avg Activity: 38 / 50 = 0.760
# ======================================================================================================
#
# Accuracy (bonus w/ relu): 91.36

# %% [markdown]
# #Part 6: Creating a CLDNN

# %% [markdown]
# Run the code in the block below 'as is.' After executing, the high SNR RadioML training and testing data will be stored in the arrays X_train and X_test, respectively. Their respective one-hot labels will be stored in Y_train and Y_test.

# %%
# Download RML 2016.10b dataset and untar file
# !wget http://opendata.deepsig.io/datasets/2016.10/RML2016.10b.tar.bz2
# !wget --no-check-certificate https://f002.backblazeb2.com/file/deepsig-datasets/2016.10/RML2016.10b.tar.bz2?Authorization=3_20210916115247_84b50b3812dca07b9149063a_1c5208f20c8e87b4a5b3693f313c0b153d82004d_002_20210916125247_0027_dnld \
      -O RML2016.10b.tar.bz2
# !tar -xvjf RML2016.10b.tar.bz2
# Out:
# --2021-09-16 11:53:17--  https://f002.backblazeb2.com/file/deepsig-datasets/2016.10/RML2016.10b.tar.bz2?Authorization=3_20210916115247_84b50b3812dca07b9149063a_1c5208f20c8e87b4a5b3693f313c0b153d82004d_002_20210916125247_0027_dnld
# Resolving f002.backblazeb2.com (f002.backblazeb2.com)... 206.190.215.16
# Connecting to f002.backblazeb2.com (f002.backblazeb2.com)|206.190.215.16|:443... connected.
# HTTP request sent, awaiting response... 200
# Length: 1245608913 (1.2G) [application/x-bzip2]
# Saving to: ‘RML2016.10b.tar.bz2’
#
# RML2016.10b.tar.bz2 100%[===================>]   1.16G  56.3MB/s    in 22s
#
# 2021-09-16 11:53:39 (53.5 MB/s) - ‘RML2016.10b.tar.bz2’ saved [1245608913/1245608913]
#
# RML2016.10b.dat
# LICENSE.TXT

# %%
# Extract high SNR data and obtain their corresponding lables 
Xd = cPickle.load(open("RML2016.10b.dat",'rb'))
snrs, mods = map(lambda j: sorted(list(set(map(lambda x: x[j], Xd.keys())))), [1,0])
X = []
lbl = []
for mod in mods:
    for snr in snrs:
        if snr > 0:
            X.append(Xd[(mod,snr)])
            for i in range(Xd[(mod,snr)].shape[0]):  lbl.append((mod,snr))

X = np.vstack(X)

np.random.seed(2016)
n_examples = X.shape[0]
n_train = n_examples * 0.8
n_train = int(n_train)
train_idx = np.random.choice(range(0,n_examples), size=n_train, replace=False)
test_idx = list(set(range(0,n_examples))-set(train_idx))

X_train = X[train_idx]
X_test  = X[test_idx]

def to_onehot(yy):
    yy1 = np.zeros([len(yy), max(yy)+1])
    yy1[np.arange(len(yy)),yy] = 1
    return yy1

Y_train = to_onehot(map(lambda x: mods.index(lbl[x][0]), train_idx))
Y_test  = to_onehot(map(lambda x: mods.index(lbl[x][0]), test_idx))

#Re-shape data to appropriate dimensions 
X_train = X_train.reshape(432000, 2, 128, 1)
X_test  = X_test.reshape(108000, 2, 128, 1)

# %%
#Create and train model architecture
def cldnn():
    model = Sequential()
    
    model.add(Conv2D(256, (1, 3), activation='relu', use_bias = True, kernel_initializer='he_normal',input_shape=(2, 128, 1)))
    model.add(Dropout(0.2))
    model.add(Conv2D(256, (2, 3), activation='relu', kernel_initializer='he_normal'))
    model.add(Conv2D(80, (1, 3), activation='relu', use_bias = True, kernel_initializer='he_normal'))
    model.add(Dropout(0.2))
    model.add(Conv2D(80, (1, 3), activation='relu', use_bias = True, kernel_initializer='he_normal'))
    model.add(Reshape((-1, 80)))
    model.add(LSTM(50, bias_initializer='ones'))
    model.add(Dense(128, activation='relu',kernel_initializer='he_normal'))
    model.add(Dense(10, activation='softmax'))
    
    return model

# Create instance of CNN model graph
cldnn = cldnn()

# Compile model using an appropriate loss and optimizer algorithm
cldnn.compile(optimizer='rmsprop', 
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Train the model and assign training meta-data to a variable
history_6 = cldnn.fit(X_train, Y_train, 
                      validation_data = (X_test, Y_test),
                      epochs=100, batch_size=4096)

# Print accuracy of model on testing set after training 
accuracy = cldnn.evaluate(X_test, Y_test)
print("Accuracy (cldnn): {0:.2f}".format(accuracy[1] * 100))
# Out:
# Train on 432000 samples, validate on 108000 samples
# Epoch 1/100
# 432000/432000 [==============================] - 215s 498us/step - loss: 1.9442 - accuracy: 0.2328 - val_loss: 1.6289 - val_accuracy: 0.3286
# Epoch 2/100
# 432000/432000 [==============================] - 202s 468us/step - loss: 1.3600 - accuracy: 0.4200 - val_loss: 1.2039 - val_accuracy: 0.4692
# Epoch 3/100
# 432000/432000 [==============================] - 202s 468us/step - loss: 1.0937 - accuracy: 0.5258 - val_loss: 0.8726 - val_accuracy: 0.6212
# Epoch 4/100
# 432000/432000 [==============================] - 202s 468us/step - loss: 0.8642 - accuracy: 0.6168 - val_loss: 0.7591 - val_accuracy: 0.6406
# Epoch 5/100
# 432000/432000 [==============================] - 202s 467us/step - loss: 0
100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1545 - accuracy: 0.9199 - val_loss: 0.1594 - val_accuracy: 0.9186
# Epoch 86/100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1509 - accuracy: 0.9214 - val_loss: 0.1494 - val_accuracy: 0.9231
# Epoch 87/100
# 432000/432000 [==============================] - 199s 461us/step - loss: 0.1572 - accuracy: 0.9202 - val_loss: 0.1488 - val_accuracy: 0.9231
# Epoch 88/100
# 432000/432000 [==============================] - 199s 462us/step - loss: 0.1588 - accuracy: 0.9189 - val_loss: 0.1501 - val_accuracy: 0.9208
# Epoch 89/100
# 432000/432000 [==============================] - 199s 462us/step - loss: 0.1500 - accuracy: 0.9218 - val_loss: 0.1457 - val_accuracy: 0.9239
# Epoch 90/100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1453 - accuracy: 0.9236 - val_loss: 0.1465 - val_accuracy: 0.9236
# Epoch 91/100
# 432000/432000 [==============================] - 200s 463us/step - loss: 0.1470 - accuracy: 0.9228 - val_loss: 0.2110 - val_accuracy: 0.8981
# Epoch 92/100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1532 - accuracy: 0.9206 - val_loss: 0.1433 - val_accuracy: 0.9252
# Epoch 93/100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1514 - accuracy: 0.9215 - val_loss: 0.1509 - val_accuracy: 0.9177
# Epoch 94/100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1471 - accuracy: 0.9227 - val_loss: 0.1798 - val_accuracy: 0.9068
# Epoch 95/100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1717 - accuracy: 0.9175 - val_loss: 0.1826 - val_accuracy: 0.9098
# Epoch 96/100
# 432000/432000 [==============================] - 199s 462us/step - loss: 0.1415 - accuracy: 0.9250 - val_loss: 0.1499 - val_accuracy: 0.9226
# Epoch 97/100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1535 - accuracy: 0.9223 - val_loss: 0.1442 - val_accuracy: 0.9238
# Epoch 98/100
# 432000/432000 [==============================] - 200s 462us/step - loss: 0.1467 - accuracy: 0.9233 - val_loss: 0.1484 - val_accuracy: 0.9228
# Epoch 99/100
# 432000/432000 [==============================] - 199s 461us/step - loss: 0.1420 - accuracy: 0.9245 - val_loss: 0.1485 - val_accuracy: 0.9232
# Epoch 100/100
# 432000/432000 [==============================] - 199s 461us/step - loss: 0.1616 - accuracy: 0.9210 - val_loss: 0.1383 - val_accuracy: 0.9262
# 108000/108000 [==============================] - 86s 795us/step
# Accuracy (cldnn): 92.62

# %%
# Plot accuracy vs epoch

plt.figure()
plt.plot(history_6.history['accuracy'])
plt.plot(history_6.history['val_accuracy'])
plt.title('Accuracy of the Trained Model (CLDNN)')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %%
# Plot loss vs epoch

plt.figure()
plt.plot(history_6.history['loss'])
plt.plot(history_6.history['val_loss'])
plt.title('Loss of the Trained Model (CLDNN)')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], bbox_to_anchor=(1.23, 1), loc='upper right')
plt.show()

# %% [markdown]
# Answer the following questions:
#
#
#
# 1.   Is this model a good fit for the data?
#
#   ANS: Yes, this model is a good fit for the data (accuracies on both training set and testing set are close to 0.92).
#
# 2.   Give two ways to improve the robustness of the model.
#
#   ANS: First, we could improve the model's robustness by preventing overfitting. Just as in question 4-b in part 2, we could avoid the overfitting by applying regularization (adding a cost to the loss function for large weights) or using dropout layers (randomly remove certain features by setting them to zero).
#
#   Second, we could do noise injection or say data set augmentation to reduce overfitting and improve model generalization, thus improving the model robustness (a nice reference material is here [click](https://https://machinelearningmastery.com/how-to-improve-deep-learning-model-robustness-by-adding-noise/)).
